# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import io
# %cd "C:\Users\Nandi\OneDrive\Documents\dataset"
# Out:
# C:\Users\Nandi\OneDrive\Documents\dataset

# %%
Indicatorsdf=pd.read_csv("P_Popular Indicators Project.csv")

# %%
#head
Indicatorsdf.head()      #answer(b)
# Out:
#    Year  Population, total  Population growth (annual %)  \
# 0  1990           61558898                      2.352971
# 1  1991           63039751                      2.377109
# 2  1992           64543525                      2.357431
# 3  1993           66083321                      2.357658
# 4  1994           67650283                      2.343515
#
#   Surface area (sq. km)  \
# 0                300000
# 1                300000
# 2                300000
# 3                300000
# 4                300000
#
#   Poverty headcount ratio at national poverty lines (% of population)  \
# 0                                                 ..
# 1                                               34.4
# 2                                                 ..
# 3                                                 ..
# 4                                               40.6
#
#    GNI, Atlas method (current US$)  \
# 0                     5.123010e+10
# 1                     5.254164e+10
# ...

# %%
Indicatorsdf.tail()       #answer(b)
# Out:
#     Year  Population, total  Population growth (annual %)  \
# 28  2018          108568836                      1.700248
# 29  2019          110380804                      1.655184
# 30  2020          112190977                      1.626633
# 31  2021          113880328                      1.494557
# 32  2022          115559009                      1.463316
#
#    Surface area (sq. km)  \
# 28                300000
# 29                300000
# 30                300000
# 31                    ..
# 32                    ..
#
#    Poverty headcount ratio at national poverty lines (% of population)  \
# 28                                               16.7
# 29                                                 ..
# 30                                                 ..
# 31                                               18.1
# 32                                                 ..
#
#     GNI, Atlas method (current US$)  \
# 28                     3.952680e+11
# ...

# %%
Indicatorsdf.describe()    #answer(b)
# Out:
#              Year  Population, total  Population growth (annual %)  \
# count    33.00000       3.300000e+01                     33.000000
# mean   2006.00000       8.806462e+07                      1.979747
# std       9.66954       1.638004e+07                      0.309304
# min    1990.00000       6.155890e+07                      1.463316
# 25%    1998.00000       7.449192e+07                      1.743525
# 50%    2006.00000       8.790184e+07                      1.884020
# 75%    2014.00000       1.013252e+08                      2.337837
# max    2022.00000       1.155590e+08                      2.469596
#
#        GNI, Atlas method (current US$)  \
# count                     3.300000e+01
# mean                      1.984195e+11
# std                       1.324431e+11
# min                       5.123010e+10
# 25%                       9.318515e+10
# 50%                       1.311400e+11
# 75%                       3.342470e+11
# max                       4.570220e+11
#
# ...

# %%
Indicatorsdf.columns    #answer(b)
# Out:
# Index(['Year', 'Population, total', 'Population growth (annual %)',
#        'Surface area (sq. km)',
#        'Poverty headcount ratio at national poverty lines (% of population)',
#        'GNI, Atlas method (current US$)',
#        'GNI per capita, Atlas method (current US$)',
#        'GNI, PPP (current international $)',
#        'GNI per capita, PPP (current international $)',
#        'Income share held by lowest 20%',
#        'Life expectancy at birth, total (years)',
#        'Fertility rate, total (births per woman)',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Contraceptive prevalence, any method (% of married women ages 15-49)',
#        'Births attended by skilled health staff (% of total)',
#        'Mortality rate, under-5 (per 1,000 live births)',
#        'Prevalence of underweight, weight for age (% of children under 5)',
#        'Immunization, measles (% of children ages 12-23 months)',
# ...

# %%
Indicatorsdf.shape    #answer(b) 
#shape determines the number of rows and columns which are 33 rows and 61 columns
# Out:
# (33, 61)

# %%
Indicatorsdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 61 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   Year                                                                                              33 non-null     int64
#  1   Population, total                                                                                 33 non-null     int64
#  2   Population growth (annual %)                                                                      33 non-null     float64
#  3   Surface area (sq. km)                                                                             33 non-null     object
# ...

# %%
philippines_ind=Indicatorsdf[['GDP growth (annual %)','Inflation, GDP deflator (annual %)',
                     'Inflation, consumer prices (annual %)', 'Population growth (annual %)']]

# %%
philippines_ind.describe()    #answer(c)
# Out:
#        GDP growth (annual %)  Inflation, GDP deflator (annual %)  \
# count              33.000000                           33.000000
# mean                4.283112                            5.255144
# std                 3.306091                            3.581531
# min                -9.518295                           -0.719683
# 25%                 3.346451                            2.738259
# 50%                 5.086911                            5.111587
# 75%                 6.348310                            6.809622
# max                 7.570332                           16.395120
#
#        Inflation, consumer prices (annual %)  Population growth (annual %)
# count                              33.000000                     33.000000
# mean                                5.489394                      1.979747
# std                                 3.618433                      0.309304
# min                                 0.674193                      1.463316
# ...

# %%
#Histogram     #answer(c)
philippines_ind.skew()
# Out:
# GDP growth (annual %)                   -2.517562
# Inflation, GDP deflator (annual %)       1.128382
# Inflation, consumer prices (annual %)    1.930654
# Population growth (annual %)             0.169073
# dtype: float64

# %%
philippines_ind.kurt() #answer(c)
# Out:
# GDP growth (annual %)                    8.737549
# Inflation, GDP deflator (annual %)       1.943501
# Inflation, consumer prices (annual %)    5.575677
# Population growth (annual %)            -1.367809
# dtype: float64

# %%
philippines_ind.plot(kind="line") #answer(c)
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
# GDP growth (annual %)         #answer(d)
fig,ax=plt.subplots(3,1)
sns.histplot(philippines_ind.iloc[:,0],ax=ax[0])
sns.boxplot(philippines_ind.iloc[:,0],orient="h",ax=ax[1])
sns.kdeplot(philippines_ind.iloc[:,0],ax=ax[2])
# there is outlier which brings down the overall mean of the GDP growth 
#This is a negatively skewed graph which indicates the bulk of data are concentrated towards right side
#There is a increase in growth of GDP except incase of the outlier
# Out:
# <Axes: xlabel='GDP growth (annual %)', ylabel='Density'>

# %%
sns.pairplot(philippines_ind)  #answer(g)

# %%
# Inflation, GDP deflator (annual %)     #answer(d)
fig,ax=plt.subplots(3,1)
sns.histplot(philippines_ind.iloc[:,1],ax=ax[0])
sns.boxplot(philippines_ind.iloc[:,1],orient="h",ax=ax[1])
sns.kdeplot(philippines_ind.iloc[:,1],ax=ax[2])
#the GDP deflator is mostly concentrated around 2.5-7.5
# Box plot reveals that there are two outliers in the positive side 
# while the skewness is normally to a slight negative.
# Out:
# <Axes: xlabel='Inflation, GDP deflator (annual %)', ylabel='Density'>

# %%
#Inflation, consumer prices (annual %)   #answer(d)
fig,ax=plt.subplots(3,1)
sns.histplot(philippines_ind.iloc[:,2],ax=ax[0])
sns.boxplot(philippines_ind.iloc[:,2],orient="h",ax=ax[1])
sns.kdeplot(philippines_ind.iloc[:,2],ax=ax[2])
# Histogram reveals that the values are concentrated between 1 to 7.5 
#there is one outlier in the data and it is positively skewed
#due to positively skewness values are concentrated towards left
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='Density'>

# %%
#Population growth (annual %)   #answer(d)
fig,ax=plt.subplots(3,1)
sns.histplot(philippines_ind.iloc[:,3],ax=ax[0])
sns.boxplot(philippines_ind.iloc[:,3],orient="h",ax=ax[1])
sns.kdeplot(philippines_ind.iloc[:,3],ax=ax[2])
# there is no outlier 
# values are equally distributed almost 
# box plot is rightly skewed 
# population growth is almost constant throughout except a few values
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='Density'>

# %%
# Calculate Average of Inflation, consumer prices (annual %) & GDP Growth     #answer(e)
print("Inflation, consumer prices (annual %):",np.mean(philippines_ind.iloc[:,2]))
print("GDP growth (annual %):",np.mean(philippines_ind.iloc[:,0]))
# Out:
# Inflation, consumer prices (annual %): 5.489393692666667
# GDP growth (annual %): 4.283112354696969

# %%
# Calculate Average of Inflation, consumer prices (annual %) & GDP Growth
print("Inflation, consumer prices (annual %):",np.var(philippines_ind.iloc[:,2]))
print("GDP growth (annual %):",np.var(philippines_ind.iloc[:,0]))
# Out:
# Inflation, consumer prices (annual %): 12.696299824883557
# GDP growth (annual %): 10.599020308073959

# %%
# From the two data Inflation has increased significantly, but GDP growth has also increased.
#Test Null Average Inflation, consumer prices (annual %) & GDP Growth are Equal - 2 Sample Ind TTest
from scipy.stats import ttest_ind

# %%
ttest_ind(philippines_ind.iloc[:,0],philippines_ind.iloc[:,2],equal_var=False)
# Since pvalue=0.16230453948428655 > 0.05 , hence fail to reject null
# The above two statements is to test null hypothesis whether 
# the mean of above two variables are equal or not considering variances are unequal
# Since, we have failed to reject null hypothesis, it help us to understand that 
# the mean of both variables is equal and is statistically significant.
# Out:
# Ttest_indResult(statistic=-1.4138041647429607, pvalue=0.16230453948428655)

# %%
print("Inflation, consumer prices (annual %):",np.var(philippines_ind.iloc[:,2]))    #answer(f)
print("Inflation, GDP deflator (annual %):",np.var(philippines_ind.iloc[:,1]))
print("GDP growth (annual %):",np.var(philippines_ind.iloc[:,0]))
print("Population growth (annual %):",np.var(philippines_ind.iloc[:,3]))
# Out:
# Inflation, consumer prices (annual %): 12.696299824883557
# Inflation, GDP deflator (annual %): 12.438657221434704
# GDP growth (annual %): 10.599020308073959
# Population growth (annual %): 0.09277005469972598

# %%
from scipy.stats import f_oneway

# %%
f_oneway(philippines_ind.iloc[:,0],philippines_ind.iloc[:,1],philippines_ind.iloc[:,2],
        philippines_ind.iloc[:,3])
# Since pvalue=1.529881774452971e-05 < .05 hence reject null hypothesis
# Means considering differences as unequal, we can say that mean between variables
# are unequal and the inequality is statistically significant with only 5% of Type 1 error.
# only 5% of the time we are going to reject the null hypothesis when they are actually correct.
# Out:
# F_onewayResult(statistic=9.171892354830048, pvalue=1.529881774452971e-05)

# %%
philippines_ind.corr() #answer(h)
# Out:
#                                        GDP growth (annual %)  \
# GDP growth (annual %)                               1.000000
# Inflation, GDP deflator (annual %)                 -0.295456
# Inflation, consumer prices (annual %)              -0.318241
# Population growth (annual %)                       -0.270563
#
#                                        Inflation, GDP deflator (annual %)  \
# GDP growth (annual %)                                           -0.295456
# Inflation, GDP deflator (annual %)                               1.000000
# Inflation, consumer prices (annual %)                            0.957181
# Population growth (annual %)                                     0.754597
#
#                                        Inflation, consumer prices (annual %)  \
# GDP growth (annual %)                                              -0.318241
# Inflation, GDP deflator (annual %)                                  0.957181
# ...

# %%
philippines_ind.cov()   #answer(h)
# Out:
#                                        GDP growth (annual %)  \
# GDP growth (annual %)                              10.930240
# Inflation, GDP deflator (annual %)                 -3.498461
# Inflation, consumer prices (annual %)              -3.807071
# Population growth (annual %)                       -0.276674
#
#                                        Inflation, GDP deflator (annual %)  \
# GDP growth (annual %)                                           -3.498461
# Inflation, GDP deflator (annual %)                              12.827365
# Inflation, consumer prices (annual %)                           12.404616
# Population growth (annual %)                                     0.835930
#
#                                        Inflation, consumer prices (annual %)  \
# GDP growth (annual %)                                              -3.807071
# Inflation, GDP deflator (annual %)                                 12.404616
# ...

# %%
sns.heatmap(philippines_ind.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8, 6))    #answer(g)
plt.scatter(philippines_ind['GDP growth (annual %)'],philippines_ind['Inflation, GDP deflator (annual %)'], c='blue', marker='o', alpha=0.7)
plt.xlabel('GDP Growth (annual %)')
plt.ylabel('Inflation, GDP Deflator (annual %)')
plt.title('Scatter Plot: GDP Growth vs. Inflation (GDP Deflator)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6)) #answer (i)
plt.plot(Indicatorsdf['Year'],Indicatorsdf['Exports of goods and services (% of GDP)'], marker='o', label='Exports')
plt.plot(Indicatorsdf['Year'],Indicatorsdf['Imports of goods and services (% of GDP)'], marker='o', label='Imports')
plt.xlabel('Year')
plt.ylabel('Percentage of GDP')
plt.title('Trend Analysis: Exports vs. Imports')
plt.legend()
plt.grid(True)
plt.show()
# imports are higher than exports from 1990 to 2005. In between 2005-2010 exports saw a slight increase than imports
# After 2010 imports are rising and exports are going down. Imports are now all time high

# %%
Indicatorsdf['CO2 emissions (metric tons per capita)'] = pd.to_numeric(Indicatorsdf['CO2 emissions (metric tons per capita)'], errors='coerce')

# %%
Indicatorsdf['CO2 emissions (metric tons per capita)'].describe()#answer(j)
# Out:
# count    31.000000
# mean      0.924627
# std       0.174096
# min       0.641535
# 25%       0.821731
# 50%       0.883117
# 75%       0.998281
# max       1.321528
# Name: CO2 emissions (metric tons per capita), dtype: float64

# %%
Indicatorsdf['CO2 emissions (metric tons per capita)']=Indicatorsdf['CO2 emissions (metric tons per capita)'].fillna(Indicatorsdf['CO2 emissions (metric tons per capita)'].mean())

# %%
Indicatorsdf['CO2 emissions (metric tons per capita)'].describe()  #answer(j)
#after converting the datatype to float from object 
#The missing value is replaced with the mean of the column
# Out:
# count    33.000000
# mean      0.924627
# std       0.168568
# min       0.641535
# 25%       0.822329
# 50%       0.883249
# 75%       0.991654
# max       1.321528
# Name: CO2 emissions (metric tons per capita), dtype: float64

# %%
plt.figure(figsize=(12, 6))   #answer(j)
plt.plot(Indicatorsdf['Year'], Indicatorsdf['CO2 emissions (metric tons per capita)'], marker='o', linestyle='-', color='b')
plt.title('CO2 Emissions Over Time')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (Million Metric Tons)')
plt.grid(True)
plt.show()
#It can be concluded from the graph that
#CO2 emissions has significantly increase after 2010
#reached maximum in 2019 followed by a certain drop

# %%
phillipines_des=Indicatorsdf[['Population growth (annual %)','CO2 emissions (metric tons per capita)',
                 'GDP growth (annual %)','Industry (including construction), value added (% of GDP)',
                 'Exports of goods and services (% of GDP)','Imports of goods and services (% of GDP)',
                 'Gross capital formation (% of GDP)','Inflation, consumer prices (annual %)']] #answer(k)

# %%
phillipines_des.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 8 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Population growth (annual %)                               33 non-null     float64
#  1   CO2 emissions (metric tons per capita)                     33 non-null     float64
#  2   GDP growth (annual %)                                      33 non-null     float64
#  3   Industry (including construction), value added (% of GDP)  33 non-null     float64
#  4   Exports of goods and services (% of GDP)                   33 non-null     float64
#  5   Imports of goods and services (% of GDP)                   33 non-null     float64
#  6   Gross capital formation (% of GDP)                         33 non-null     float64
# ...

# %%
y=Indicatorsdf['GDP growth (annual %)']

# %%
x=Indicatorsdf[['Population growth (annual %)','CO2 emissions (metric tons per capita)',
                 'Industry (including construction), value added (% of GDP)',
                 'Exports of goods and services (% of GDP)','Imports of goods and services (% of GDP)',
                 'Gross capital formation (% of GDP)','Inflation, consumer prices (annual %)']]

# %%
x.corr()
# Out:
#                                                     Population growth (annual %)  \
# Population growth (annual %)                                            1.000000
# CO2 emissions (metric tons per capita)                                 -0.488755
# Industry (including construction), value added ...                      0.926010
# Exports of goods and services (% of GDP)                                0.043294
# Imports of goods and services (% of GDP)                               -0.168237
# Gross capital formation (% of GDP)                                     -0.087854
# Inflation, consumer prices (annual %)                                   0.619919
#
#                                                     CO2 emissions (metric tons per capita)  \
# Population growth (annual %)                                                     -0.488755
# CO2 emissions (metric tons per capita)                                            1.000000
# ...

# %%
# Since, in none of the pair of variables, correlation is more than .95. 
# Thus, we can say that that no multicollinearity exists.

# %%
from sklearn.linear_model import LinearRegression  #answer(l)
# Multiple linear regression.

# %%
reg=LinearRegression()

# %%
regmodel=reg.fit(x,y)

# %%
regmodel.score(x,y) 
# Since R square value is 0.6324769047972499. So, the independent variables
# can explain 63%of the changes in independent variable i.e. GDP growth.
# Out:
# 0.6324769047972499

# %%
regpredict=regmodel.predict(x)

# %%
regresidual=regmodel.predict(x)

# %%
regresidual=y-regpredict

# %%
np.sqrt(np.mean(regresidual**2)) 
# RMSE takes into consideration the square of error in forecasted 
# value over actual values. Thus, gives a much more accuracy.
# In this case case is very low which teels that our model is accurately
# able to predict the values with existing variables 
# but must be considered in context of R square.
# Out:
# 1.973672908498302

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree=DecisionTreeRegressor()

# %%
treemodel=tree.fit(x,y)

# %%
treemodel.score(x,y)
# Since, getting a score of 1 is next to impossible in real life situation.
# Thus, we can interpret that decision tree has led to overfitting.
# So, we need to specify the depth to limit the clusters it forms.
# Out:
# 1.0

# %%
tree2=DecisionTreeRegressor(max_depth=4)
#Reducing the depth to 4 we get the score within the range i.e 0.6-0.95

# %%
tree2model=tree2.fit(x,y)

# %%
tree2model.score(x,y)
# Out:
# 0.9488763001035551

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF=RandomForestRegressor(n_estimators=1000)

# %%
RFmodel=RF.fit(x,y)

# %%
RFmodel.score(x,y)
# The score is low compared to decision tree for random forest 
# as it does not lead to overfitting. Thus, they are robust 
# since they consider various parameters as well as random subset of training data to form decision tree.
# Out:
# 0.8663338184729874

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbm=GradientBoostingRegressor(n_estimators=3000)

# %%
gbmodel=gbm.fit(x,y)

# %%
gbmodel.score(x,y)
# Since, the result we get from Gradient Boosting Method is 0.999999. 
# Thus, we can conveniently conclude that the method has accurately read
# the training data as it corrects the errors made by previous trees. But such
# high levels of accuracy can be a sign of overfitting.
# Out:
# 1.0

# %%
# So, from all the above models I can say that Random Forest is best model.
